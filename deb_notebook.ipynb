# %%
from deb.simulations import simulate, plot_res, aux, allStat
import pandas as pd

# %%
species = "Sparus_aurata"
location = "Temp_Vrgada.csv"
f_rez = simulate(species, location, initial_size = 1)

# %%
plot_res(f_rez, species, location, aux)

# %%
species = pd.read_csv("data/species_list_hrv.csv", index_col=0)
species
# Out:
#                       species
# 0          Argyrosomus regius
# 1             Chelon labrosus
# 2               Dentex dentex
# 3        Dicentrarchus labrax
# 4           Diplodus puntazzo
# 5             Diplodus sargus
# 6           Diplodus vulgaris
# 7                Gadus morhua
# 8   Hippoglossus hippoglossus
# 9       Lithognathus mormyrus
# 10                Liza aurata
# 11                Liza ramado
# 12             Mugil cephalus
# 13            Oblada melanura
# 14        Oncorhynchus mykiss
# 15        Pagellus erythrinus
# 16              Pagrus pagrus
# 17         Platichthys flesus
# 18       Polyprion americanus
# 19                Salmo salar
# 20               Salmo trutta
# 21                Sarpa salpa
# 22              Sciaena umbra
# 23       Scophthalmus maximus
# 24           Seriola dumerili
# 25            Seriola lalandi
# 26                Solea solea
# 27              Sparus aurata
# 28          Thunnus albacares
# 29         Thunnus orientalis
# 30            Thunnus thynnus
# 31            Umbrina cirrosa

# %%
for i in species["species"]:
    sp = i.replace(" ", "_")
    try:
        allStat[sp]
    except KeyError:
        print(sp)
# Out:
# Liza_aurata
# Liza_ramado
# Oblada_melanura
# Pagrus_pagrus
# Platichthys_flesus
# Seriola lalandi
# Umbrina_cirrosa

# %% [markdown]
# Vrste kojih nema u `allStat` varijabli
#
# - Zlatni cipal
# - Cipal balavac
# - Ušata
# - Pagara
# - List
# - Koraf

# %%
species_with_deb = []
for i in species["species"]:
    sp = i.replace(" ", "_")
    try:
        f_rez = simulate(sp, location, initial_size = 1)
        plot_res(f_rez, sp, location, aux)
        species_with_deb.append(sp)
    except KeyError:
        print("Failed", sp)
# Out:
# Failed Chelon_labrosus
# Failed Liza_aurata
# Failed Liza_ramado
# Failed Mugil_cephalus
# Failed Oblada_melanura
# Failed Pagrus_pagrus
# Failed Platichthys_flesus
# /home/domagoj/development/BlueCloudHackathon_i/deb/dydt_KDEB.py:47: RuntimeWarning: invalid value encountered in double_scalars
#   pX = f * p_XmT * V**(2/3)
# /home/domagoj/development/BlueCloudHackathon_i/deb/dydt_KDEB.py:51: RuntimeWarning: invalid value encountered in double_scalars
#   pT = p_TT * V**(2/3)
# /home/domagoj/development/BlueCloudHackathon_i/deb/dydt_KDEB.py:54: RuntimeWarning: invalid value encountered in double_scalars
#   pC = (E/V) * (p["E_G"] * v_T * V**(2/3) + pS ) / (p["kap"] * E/V + p["E_G"])
# Failed Seriola lalandi
# Failed Umbrina_cirrosa

# %%
for i in species_with_deb:
    print(i)
# Out:
# Argyrosomus_regius
# Dentex_dentex
# Dicentrarchus_labrax
# Diplodus_puntazzo
# Diplodus_sargus
# Diplodus_vulgaris
# Gadus_morhua
# Hippoglossus_hippoglossus
# Lithognathus_mormyrus
# Oncorhynchus_mykiss
# Pagellus_erythrinus
# Polyprion_americanus
# Salmo_salar
# Salmo_trutta
# Sarpa_salpa
# Sciaena_umbra
# Scophthalmus_maximus
# Seriola_dumerili
# Solea_solea
# Sparus_aurata
# Thunnus_albacares
# Thunnus_orientalis
# Thunnus_thynnus
